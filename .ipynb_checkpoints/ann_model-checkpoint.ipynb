# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Example data
x = [[1],[2],[3],[4],[5]]
y = [[2],[4],[6],[8],[10]]

# Build ANN model
model = Sequential([
    Dense(8, activation='relu', input_shape=(1,)),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# Train model
model.fit(x, y, epochs=200)

# Test
print("Prediction for 6:", model.predict([[6]]))

# %%
#implementation of logical gate without using activation fuction (linear model)
#import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# AND gate data
X = np.array([[0,0],[0,1],[1,0],[1,1]])
Y = np.array([[0],[0],[0],[1]])

# Model WITHOUT activation function
model = Sequential()
model.add(Dense(1, input_dim=2))   # No activation

model.compile(optimizer='adam', loss='mse')

# Train
model.fit(X, Y, epochs=1000, verbose=0)

# Test
print("Predictions without activation:")
print(model.predict(X))

# %%
#implementation of logical gate using activation fuction (sigmoid)
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# AND gate data
X = np.array([[0,0],[0,1],[1,0],[1,1]])
Y = np.array([[0],[0],[0],[1]])

# Model WITH activation function
model = Sequential()
model.add(Dense(1, input_dim=2, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy')

# Train
model.fit(X, Y, epochs=1000, verbose=0)

# Test
print("Predictions with activation:")
print(model.predict(X))
